# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import urllib.request

# %%
urllib.request.urlretrieve('http://vision.ucsd.edu/extyaleb/CroppedYaleBZip/CroppedYale.zip', 'CroppedYaleBZip.zip')
# Out:
# ('CroppedYaleBZip.zip', <http.client.HTTPMessage at 0x7fa4d6439c10>)

# %%
# !unzip CroppedYaleBZip.zip -d /content/gdrive/Shareddrives/DB-LARC/
# Out:
# Archive:  CroppedYaleBZip.zip
#    creating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/WS_FTP.LOG
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00.info
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+000E+00.pgm
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+000E+20.pgm
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+000E+45.pgm
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+000E+90.pgm
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+000E-20.pgm
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+000E-35.pgm
#   inflating: /content/gdrive/Shareddrives/DB-LARC/CroppedYale/yaleB39/yaleB39_P00A+005E+10.pgm
# ...
